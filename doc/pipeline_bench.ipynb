# %%
#  pip install jupyterlab_widgets
# start this notebook with
# $> jupyter lab

# give us interactive plots in jupyter lab:
# %matplotlib widget
# %load_ext autoreload
import matplotlib
import numpy
import json
import matplotlib.pyplot as plt

# %%
import importlib
import helper_libs as util
importlib.reload(util)
# %autoreload 1
# %aimport helper_libs
# Out:
# Module re-loaded
# Module re-loaded

# %%
# Many open interactive plots take lots of memory.  Close them occasionally by running this block
matplotlib.pyplot.close('all')

# %%
dat64 = util.load_pipeline_file('/fsx/lrbison/lrbison_benchmarks/src/results_bench_pipeline_64r.json')
dat32 = util.load_pipeline_file('/fsx/lrbison/lrbison_benchmarks/src/results_bench_pipeline_32r.json')
dat16 = util.load_pipeline_file('/fsx/lrbison/lrbison_benchmarks/src/results_bench_pipeline_16r.json')
dat8 = util.load_pipeline_file('/fsx/lrbison/lrbison_benchmarks/src/results_bench_pipeline_8r.json')
dat4 = util.load_pipeline_file('/fsx/lrbison/lrbison_benchmarks/src/results_bench_pipeline_4r.json')
dat2 = util.load_pipeline_file('/fsx/lrbison/lrbison_benchmarks/src/results_bench_pipeline_2r.json')

# %%
dat2['ntrials']
# Out:
# 200

# %%
dat2['results'][0]['bandwidths'].shape
# Out:
# (2, 200)

# %%
nres = len(dat8['results'])
for jres in range(nres):
    plt.figure()
    util.plot_res_vs_trial(dat64['results'][jres],dat64,'bandwidths')
# Out:
# /tmp/ipykernel_801458/1490433272.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
nres = len(dat2['results'])
for jres in range(nres):
    plt.figure()
    util.plot_res_vs_rank(dat64['results'][jres],dat64,'bandwidths')
# Out:
# /tmp/ipykernel_801458/367440398.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
util.bar_res_vs_bufsize(dat2,"bandwidths")
util.bar_res_vs_bufsize(dat4,"bandwidths")
util.bar_res_vs_bufsize(dat8,"bandwidths")
util.bar_res_vs_bufsize(dat16,"bandwidths")
util.bar_res_vs_bufsize(dat32,"bandwidths")
util.bar_res_vs_bufsize(dat64,"bandwidths")

# %%
util.bar_res_vs_tmpspace(dat2,"bandwidths")
util.bar_res_vs_tmpspace(dat8,"bandwidths")
